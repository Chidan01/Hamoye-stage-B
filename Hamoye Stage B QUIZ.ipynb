# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %matplotlib inline

# %%
energy_data = pd.read_csv('energydata_complete.csv')
energy_data
# Out:
#                       date  Appliances  lights         T1       RH_1  \
# 0      2016-01-11 17:00:00          60      30  19.890000  47.596667
# 1      2016-01-11 17:10:00          60      30  19.890000  46.693333
# 2      2016-01-11 17:20:00          50      30  19.890000  46.300000
# 3      2016-01-11 17:30:00          50      40  19.890000  46.066667
# 4      2016-01-11 17:40:00          60      40  19.890000  46.333333
# ...                    ...         ...     ...        ...        ...
# 19730  2016-05-27 17:20:00         100       0  25.566667  46.560000
# 19731  2016-05-27 17:30:00          90       0  25.500000  46.500000
# 19732  2016-05-27 17:40:00         270      10  25.500000  46.596667
# 19733  2016-05-27 17:50:00         420      10  25.500000  46.990000
# 19734  2016-05-27 18:00:00         430      10  25.500000  46.600000
#
#               T2       RH_2         T3       RH_3         T4  ...         T9  \
# ...

# %%
energy_data.shape
# Out:
# (19735, 29)

# %%
energy_data.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# ...

# %%
energy_data.head(10)
# Out:
#                   date  Appliances  lights         T1       RH_1     T2  \
# 0  2016-01-11 17:00:00          60      30  19.890000  47.596667  19.20
# 1  2016-01-11 17:10:00          60      30  19.890000  46.693333  19.20
# 2  2016-01-11 17:20:00          50      30  19.890000  46.300000  19.20
# 3  2016-01-11 17:30:00          50      40  19.890000  46.066667  19.20
# 4  2016-01-11 17:40:00          60      40  19.890000  46.333333  19.20
# 5  2016-01-11 17:50:00          50      40  19.890000  46.026667  19.20
# 6  2016-01-11 18:00:00          60      50  19.890000  45.766667  19.20
# 7  2016-01-11 18:10:00          60      50  19.856667  45.560000  19.20
# 8  2016-01-11 18:20:00          60      40  19.790000  45.597500  19.20
# 9  2016-01-11 18:30:00          70      40  19.856667  46.090000  19.23
#
#         RH_2     T3       RH_3         T4  ...         T9   RH_9     T_out  \
# 0  44.790000  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000
# ...

# %%
energy_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  object
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
# ...

# %%
#checking for missing data
energy_data.isnull().sum()
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
#To get the columns names
energy_data.columns
# Out:
# Index(['date', 'Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3',
#        'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8',
#        'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed',
#        'Visibility', 'Tdewpoint', 'rv1', 'rv2'],
#       dtype='object')

# %%
columns_name={ 'x2':'Appliances', 'x3':'lights','x4':'T1', 'x5':'RH_1', 'x6':'T2', 'x7':'RH_2', 'x8':'T3', 'x9':'RH_3', 
              'x10':'T4', 'x11':'RH_4', 'x12':'T5', 'x13':'RH_5', 'x14':'T6','x15':'RH_6', 'x16':'T7', 'x17':'RH_7','x18':'T8',
              'x19':'RH_8','x20':'T9','x21':'RH_9','x22':'T_out','x23':'Press_mm_hg','x24':'RH_out','x25':'Windspeed','x26':'Visibility',
              'x27':'Tdewpoint','y1':'rv1', 'y2':'rv2'}

# %%
columns_name['x2']
# Out:
# 'Appliances'

# %%
columns=list(energy_data.columns)[1:]
columns
# Out:
# ['Appliances',
#  'lights',
#  'T1',
#  'RH_1',
#  'T2',
#  'RH_2',
#  'T3',
#  'RH_3',
#  'T4',
#  'RH_4',
#  'T5',
#  'RH_5',
#  'T6',
#  'RH_6',
#  'T7',
#  'RH_7',
#  'T8',
#  'RH_8',
#  'T9',
#  'RH_9',
#  'T_out',
#  'Press_mm_hg',
#  'RH_out',
#  'Windspeed',
#  'Visibility',
#  'Tdewpoint',
#  'rv1',
#  'rv2']

# %%
normalised_data=energy_data.drop(columns=['date','lights'])
columns
# Out:
# ['Appliances',
#  'lights',
#  'T1',
#  'RH_1',
#  'T2',
#  'RH_2',
#  'T3',
#  'RH_3',
#  'T4',
#  'RH_4',
#  'T5',
#  'RH_5',
#  'T6',
#  'RH_6',
#  'T7',
#  'RH_7',
#  'T8',
#  'RH_8',
#  'T9',
#  'RH_9',
#  'T_out',
#  'Press_mm_hg',
#  'RH_out',
#  'Windspeed',
#  'Visibility',
#  'Tdewpoint',
#  'rv1',
#  'rv2']

# %%
normalised_data
# Out:
#        Appliances         T1       RH_1         T2       RH_2         T3  \
# 0              60  19.890000  47.596667  19.200000  44.790000  19.790000
# 1              60  19.890000  46.693333  19.200000  44.722500  19.790000
# 2              50  19.890000  46.300000  19.200000  44.626667  19.790000
# 3              50  19.890000  46.066667  19.200000  44.590000  19.790000
# 4              60  19.890000  46.333333  19.200000  44.530000  19.790000
# ...           ...        ...        ...        ...        ...        ...
# 19730         100  25.566667  46.560000  25.890000  42.025714  27.200000
# 19731          90  25.500000  46.500000  25.754000  42.080000  27.133333
# 19732         270  25.500000  46.596667  25.628571  42.768571  27.050000
# 19733         420  25.500000  46.990000  25.414000  43.036000  26.890000
# 19734         430  25.500000  46.600000  25.264286  42.971429  26.823333
#
#             RH_3         T4       RH_4         T5  ...         T9     RH_9  \
# ...

# %%
#checking the regression for a single variable, and a plot of rv1 against T1
simple_linear_reg= energy_data[['T1','Appliances']].sample(50, random_state=2)
sns.regplot(x='T1', y='Appliances', data=simple_linear_reg)
# Out:
# <AxesSubplot:xlabel='T1', ylabel='Appliances'>

# %%
simple_linear_reg= energy_data[['T2','Appliances']].sample(50, random_state=2)
sns.regplot(x='T2', y='Appliances', data=simple_linear_reg)
# Out:
# <AxesSubplot:xlabel='T2', ylabel='Appliances'>

# %%
simple_linear_reg= energy_data[['RH_1','Appliances']].sample(50, random_state=2)
sns.regplot(x='RH_1', y='Appliances', data=simple_linear_reg)
# Out:
# <AxesSubplot:xlabel='RH_1', ylabel='Appliances'>

# %%
plt.figure(figsize = (20, 20))
sns.heatmap(normalised_data.corr(method = 'pearson'), annot = True, linewidths=2, linecolor='purple')
plt.show()
plt.close()

# %% [markdown]
# #some inferences which can be drawn include the following;
# - All features shows little correlation with the Appliances feature(target)
# - The relative temperature and relative humidity shows great correlation between them
# - The random variables shows no significant correlation with other features.
# - The visibility feature had little correlation with the relative humidity and temperature, and had a very weak correlation with the Appliances feature
# - The pressure feature and the windspeed didn't give better correlation relationship with other features.
# - The dewpoint seems to show a quite reasonable correlation with the relative humidity and temperature, but a weak correlation with the Appliances Feature.

# %%
#scaling of numeric data
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
new_energy_data =pd.DataFrame(scaler.fit_transform(normalised_data), columns=normalised_data.columns)

# %%
input_cols= new_energy_data.drop(columns=['Appliances'])

# %%
target_col = new_energy_data['Appliances']

# %%
target_col
# Out:
# 0        0.046729
# 1        0.046729
# 2        0.037383
# 3        0.037383
# 4        0.046729
#            ...
# 19730    0.084112
# 19731    0.074766
# 19732    0.242991
# 19733    0.383178
# 19734    0.392523
# Name: Appliances, Length: 19735, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test =train_test_split(input_cols,target_col, test_size=0.3, random_state=42 )

# %%
x_train.head(10)
# Out:
#              T1      RH_1        T2      RH_2        T3      RH_3        T4  \
# 9129   0.497360  0.236767  0.122850  0.565939  0.373878  0.303474  0.476577
# 2453   0.286167  0.482616  0.188999  0.669978  0.217957  0.735317  0.270270
# 9152   0.422386  0.230529  0.057427  0.606430  0.373878  0.338059  0.414414
# 12694  0.560718  0.446840  0.280834  0.704002  0.514290  0.515189  0.540541
# 16952  0.835269  0.422071  1.000000  0.318493  0.745383  0.459106  0.900901
# 360    0.191130  0.421154  0.138115  0.594058  0.207710  0.674560  0.279279
# 5007   0.307286  0.381892  0.213230  0.499578  0.326797  0.512074  0.354354
# 14816  0.633580  0.320338  0.420887  0.441278  0.625623  0.281508  0.675676
# 14538  0.662795  0.217595  0.522656  0.326928  0.481888  0.308303  0.701802
# 289    0.263992  0.377213  0.188999  0.542600  0.173646  0.619878  0.351351
#
#            RH_4        T5      RH_5  ...        T9      RH_9     T_out  \
# ...

# %%
y_train
# Out:
# 9129     0.037383
# 2453     0.018692
# 9152     0.028037
# 12694    0.102804
# 16952    0.037383
#            ...
# 11284    0.046729
# 11964    0.102804
# 5390     0.018692
# 860      0.065421
# 15795    0.112150
# Name: Appliances, Length: 13814, dtype: float64

# %%
from sklearn import linear_model
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
predicted_values = model.predict(x_test)
predicted_values
# Out:
# array([0.03322207, 0.24411599, 0.03400024, ..., 0.06844707, 0.10032325,
#        0.05722198])

# %%
model.score(x_test, y_test)
# Out:
# 0.14890246319303535

# %%
T2=pd.DataFrame(x_train["T2"])
T2
# Out:
#              T2
# 9129   0.122850
# 2453   0.188999
# 9152   0.057427
# 12694  0.280834
# 16952  1.000000
# ...         ...
# 11284  0.239157
# 11964  0.428883
# 5390   0.152653
# 860    0.315047
# 15795  0.275503
#
# [13814 rows x 1 columns]

# %%
T6 = pd.DataFrame(x_train["T6"])
T6
# Out:
#              T6
# 9129   0.180420
# 2453   0.275215
# 9152   0.131907
# 12694  0.444040
# 16952  0.944695
# ...         ...
# 11284  0.453064
# 11964  0.697375
# 5390   0.115704
# 860    0.211468
# 15795  0.493524
#
# [13814 rows x 1 columns]

# %%
T6_test = pd.DataFrame(x_test["T6"])

# %%
T2_test = pd.DataFrame(x_test["T2"])

# %%
model.fit(T2, T6)
# Out:
# LinearRegression()

# %%
new_vals = model.predict(T2_test)

# %%
r2_score = r2_score(T6_test, new_vals)
round(r2_score, 2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-4a9817dd72bb> in <module>
# ----> 1 r2_score = r2_score(T6_test, new_vals)
#       2 round(r2_score, 2)
#
# NameError: name 'r2_score' is not defined

# %%
from sklearn.metrics import mean_absolute_error

# %%
MAE=mean_absolute_error(y_test, predicted_values)
round(MAE, 2)
# Out:
# 0.05

# %%
RSS = np.sum(np.square(y_test-predicted_values))
round(RSS, 2)
# Out:
# 45.35

# %%
from sklearn.metrics import mean_squared_error
RMSE =mean_squared_error

# %%
rmse = np.sqrt(RMSE(y_test, predicted_values))
round(rmse, 3)
# Out:
# 0.088

# %%
from sklearn.metrics import r2_score
r2_score = r2_score(y_test, predicted_values)
round(r2_score, 2)
# Out:
# 0.15

# %%
from sklearn.linear_model import Ridge

# %%
# ?pip Ridge
# Out:
# Object `pip Ridge` not found.

# %%
ridge_reg = Ridge(alpha=0.4)
ridge_reg.fit(x_train, y_train)
# Out:
# Ridge(alpha=0.4)

# %%
pred_val =ridge_reg.predict(x_test)

# %%
MAE=mean_absolute_error(y_test, pred_val)
round(MAE, 2)
# Out:
# 0.05

# %%
from sklearn.linear_model import Lasso

# %%
lasso_reg = Lasso(alpha = 0.001)
lasso_reg.fit(x_train, y_train)
# Out:
# Lasso(alpha=0.001)

# %%
def get_weights_df(model, feat, col_name):
    weights = pd.Series(model.coef_, feat.columns).sort_values()
    weights_df = pd.DataFrame(weights).reset_index()
    weights_df.columns = ['input_cols', col_name]
    weights_df[col_name].round(4)
    return weights_df

# %%
linear_model_weights = get_weights_df(model, x_train, 'Linear_Model_Weight')
ridge_weights_df = get_weights_df(ridge_reg, x_train, 'Ridge_Weight')
lasso_weights_df = get_weights_df(lasso_reg, x_train, 'Lasso_Weight')

# %%
final_weights = pd.merge(linear_model_weights, ridge_weights_df, on='input_cols')
final_weights = pd.merge(final_weights, lasso_weights_df, on ='input_cols')
final_weights
# Out:
#      input_cols  Linear_Model_Weight  Ridge_Weight  Lasso_Weight
# 0          RH_2            -0.456698     -0.411071     -0.000000
# 1         T_out            -0.321860     -0.262172      0.000000
# 2            T2            -0.236178     -0.201397      0.000000
# 3            T9            -0.189941     -0.188916     -0.000000
# 4          RH_8            -0.157595     -0.156830     -0.000110
# 5        RH_out            -0.077671     -0.054724     -0.049557
# 6          RH_7            -0.044614     -0.045977     -0.000000
# 7          RH_9            -0.039800     -0.041367     -0.000000
# 8            T5            -0.015657     -0.019853     -0.000000
# 9            T1            -0.003281     -0.018406      0.000000
# 10          rv2             0.000770      0.000748     -0.000000
# 11          rv1             0.000770      0.000748     -0.000000
# 12  Press_mm_hg             0.006839      0.006584     -0.000000
# ...

# %%
estimated_val=lasso_reg.predict(x_test)

# %%
rmse = np.sqrt(RMSE(y_test, estimated_val))
round(rmse, 3)
# Out:
# 0.094
